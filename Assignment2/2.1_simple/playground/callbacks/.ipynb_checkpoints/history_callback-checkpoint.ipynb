# %%
# import keras library
import keras
# import Sequential from the keras models module
from keras import Sequential
# import Dense, Dropout, Flatten, Conv2D, MaxPooling2D from the keras layers module
from keras.layers import Dense,Flatten, Conv2D
import matplotlib.pyplot as plt

# %%
import numpy as np
import pandas as pd
y = pd.read_csv("C:/Users/david/Documents/0_kul/1_ma_stds_1/1_advanced_analytics/assignment_2/data/simple/y.csv",delimiter=',')
x = np.load('C:/Users/david/Documents/0_kul/1_ma_stds_1/1_advanced_analytics/assignment_2/data/simple/image_pixel_100.npy') # loading it
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3,random_state=42)

# %%
# examine number of samples in train, test, and validation sets
print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
# Out:
# x_train shape: (590, 100, 100, 3)
# 590 train samples
# 253 test samples

# %%
model = Sequential()
# Add a convolutional layer (15 units)
model.add(Conv2D(25,activation='relu',kernel_size=3,input_shape=(100,100,3)))
# Add another convolutional layer (5 units)
model.add(Conv2D(10,activation='relu',kernel_size=2))
# Add another convolutional layer (5 units)
model.add(Flatten())
model.add(Dense(3, activation='softmax'))
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_3 (Conv2D)            (None, 98, 98, 25)        700
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 97, 97, 10)        1010
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 94090)             0
# _________________________________________________________________
# dense_2 (Dense)              (None, 3)                 282273
# =================================================================
# Total params: 283,983
# Trainable params: 283,983
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile model
model.compile(optimizer='rmsprop', 
              loss='categorical_crossentropy', 
              metrics=['accuracy'])

# %%
# Train your model and save its history
h_callback = model.fit(x_train,y_train,epochs = 50,
               validation_split=0.3)
# Out:
# Train on 413 samples, validate on 177 samples
# Epoch 1/50
# 413/413 [==============================] - 2s 5ms/step - loss: 203.8303 - accuracy: 0.5375 - val_loss: 15.1225 - val_accuracy: 0.6384
# Epoch 2/50
# 413/413 [==============================] - 2s 6ms/step - loss: 4.6833 - accuracy: 0.7433 - val_loss: 10.1678 - val_accuracy: 0.4746
# Epoch 3/50
# 413/413 [==============================] - 2s 5ms/step - loss: 0.8071 - accuracy: 0.9274 - val_loss: 7.6403 - val_accuracy: 0.6780
# Epoch 4/50
# 413/413 [==============================] - 2s 5ms/step - loss: 0.3640 - accuracy: 0.9661 - val_loss: 9.1562 - val_accuracy: 0.6780
# Epoch 5/50
# 413/413 [==============================] - 2s 5ms/step - loss: 1.7992 - accuracy: 0.9564 - val_loss: 10.7179 - val_accuracy: 0.6441
# Epoch 6/50
# 413/413 [==============================] - 2s 5ms/step - loss: 1.0079 - accuracy: 0.9492 - val_loss: 16.0628 - val_accuracy: 0.6780
# Epoch 7/50
# 413/413 [==============================] - 2s 5ms/step - loss: 1.6384 - accuracy: 0.8862 - val_loss: 11.2813 - val_accuracy: 0.6610
# Epoch 8/50
# 413/413 [==============================] - 2s 5ms/step - loss: 2.0537 - accuracy: 0.9225 - val_loss: 12.9153 - val_accuracy: 0.6554
# Epoch 9/50
# 413/413 [==============================] - 2s 5ms/step - loss: 0.7439 - accuracy: 0.9588 - val_loss: 25.0602 - val_accuracy: 0.6836
# Epoch 10/50
# 413/413 [==============================] - 2s 5ms/step - loss: 2.0339 - accuracy: 0.9370 - val_loss: 21.7511 - val_accuracy: 0.6328
# Epoch 11/50
# 413/413 [==============================] - 2s 5ms/step - loss: 3.5671 - accuracy: 0.9395 - val_loss: 29.6022 - val_accuracy: 0.5311
# Epoch 12/50
# 413/413 [==============================] - 2s 5ms/step - loss: 6.4829 - accuracy: 0.9128 - val_loss: 51.6685 - val_accuracy: 0.6949
# Epoch 13/50
# 413/413 [==============================] - 2s 5ms/step - loss: 5.7267 - accuracy: 0.9298 - val_loss: 35.4627 - val_accuracy: 0.6215
# 413/413 [==============================] - 2s 5ms/step - loss: 128.3401 - accuracy: 0.9201 - val_loss: 1912.5421 - val_accuracy: 0.1977
# Epoch 35/50
# 413/413 [==============================] - 2s 5ms/step - loss: 104.6057 - accuracy: 0.8983 - val_loss: 631.0291 - val_accuracy: 0.6441
# Epoch 36/50
# 413/413 [==============================] - 2s 5ms/step - loss: 211.7314 - accuracy: 0.8692 - val_loss: 689.2234 - val_accuracy: 0.6271
# Epoch 37/50
# 413/413 [==============================] - 2s 5ms/step - loss: 177.5399 - accuracy: 0.8935 - val_loss: 955.3068 - val_accuracy: 0.6949
# Epoch 38/50
# 413/413 [==============================] - 2s 5ms/step - loss: 246.5101 - accuracy: 0.8596 - val_loss: 1122.3155 - val_accuracy: 0.3898
# Epoch 39/50
# 413/413 [==============================] - 2s 5ms/step - loss: 133.7776 - accuracy: 0.9080 - val_loss: 1337.4629 - val_accuracy: 0.6836
# Epoch 40/50
# 413/413 [==============================] - 2s 6ms/step - loss: 107.2059 - accuracy: 0.9249 - val_loss: 968.1364 - val_accuracy: 0.6780
# Epoch 41/50
# 413/413 [==============================] - 3s 6ms/step - loss: 458.9992 - accuracy: 0.8257 - val_loss: 847.6036 - val_accuracy: 0.6554
# Epoch 42/50
# 413/413 [==============================] - 2s 6ms/step - loss: 52.8633 - accuracy: 0.9540 - val_loss: 3504.4760 - val_accuracy: 0.1751
# Epoch 43/50
# 413/413 [==============================] - 2s 6ms/step - loss: 403.4321 - accuracy: 0.8620 - val_loss: 758.2708 - val_accuracy: 0.4520
# Epoch 44/50
# 413/413 [==============================] - 2s 6ms/step - loss: 723.5063 - accuracy: 0.8765 - val_loss: 1148.7089 - val_accuracy: 0.6667
# Epoch 45/50
# 413/413 [==============================] - 2s 5ms/step - loss: 664.2582 - accuracy: 0.8354 - val_loss: 1288.6927 - val_accuracy: 0.6780
# Epoch 46/50
# 413/413 [==============================] - 2s 5ms/step - loss: 90.0831 - accuracy: 0.9443 - val_loss: 879.1314 - val_accuracy: 0.6328
# Epoch 47/50
# 413/413 [==============================] - 2s 5ms/step - loss: 1936.3174 - accuracy: 0.8063 - val_loss: 1083.2296 - val_accuracy: 0.6667
# Epoch 48/50
# 413/413 [==============================] - 2s 5ms/step - loss: 836.8746 - accuracy: 0.8886 - val_loss: 1748.3146 - val_accuracy: 0.6384
# Epoch 49/50
# 413/413 [==============================] - 2s 5ms/step - loss: 355.5921 - accuracy: 0.8717 - val_loss: 1075.9846 - val_accuracy: 0.6723
# Epoch 50/50
# 413/413 [==============================] - 2s 5ms/step - loss: 1335.7758 - accuracy: 0.8329 - val_loss: 1102.6066 - val_accuracy: 0.6441

# %%
def plot_loss(loss,val_loss):
  plt.figure()
  plt.plot(loss)
  plt.plot(val_loss)
  plt.title('Model loss')
  plt.ylabel('Loss')
  plt.xlabel('Epoch')
  plt.legend(['Train', 'Test'], loc='upper right')
  plt.show()

# %%
def plot_accuracy(acc,val_acc):
  # Plot training & validation accuracy values
  plt.figure()
  plt.plot(acc)
  plt.plot(val_acc)
  plt.title('Model accuracy')
  plt.ylabel('Accuracy')
  plt.xlabel('Epoch')
  plt.legend(['Train', 'Test'], loc='upper left')
  plt.show()

# %%
# Plot train vs test loss during training
plot_loss(h_callback.history['loss'], h_callback.history['val_loss'])
# Plot train vs test accuracy during training
plot_accuracy(h_callback.history['accuracy'], h_callback.history['val_accuracy'])

# %%
model.evaluate(x_train,y_train)

# %%
model.evaluate(x_test,y_test)
