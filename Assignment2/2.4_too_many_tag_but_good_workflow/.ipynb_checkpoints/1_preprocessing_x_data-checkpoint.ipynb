# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing import image

# %%
loaded_array = np.load('C:/Users/david/Documents/0_kul/1_ma_stds_1/1_advanced_analytics/assignment_2/data/processed/image_pixel.npy') # loading it

# %%
loaded_array.shape
# Out:
# (11685, 100, 100, 3)

# %%
img_data = loaded_array[64,:,:,:]
print(img_data.shape)
# Out:
# (100, 100, 3)

# %%
plt.imshow(img_data)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
img_64 = image.array_to_img(loaded_array[64,:,:,:])

# %%
img_64
# Out:
# <PIL.Image.Image image mode=RGB size=100x100 at 0x1AD9EAC85C0>
